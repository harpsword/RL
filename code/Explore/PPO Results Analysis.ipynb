# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#results = pd.read_csv("ppo-record-Amidar-v0.csv", index_col=0)
results = pd.read_csv("ppo-record-Pong-v0.csv", index_col=0)

# %%
count = {
    
}

gamelength = {}

# %%
for i in range(results.shape[0]):
    episode = results.iloc[i, 0]
    reward = results.iloc[i, 2]
    if episode not in count.keys() and episode != 0:
        count[episode] = [reward]
    elif episode in count.keys():
        count[episode].append(reward)

# %%
x = []
y = []
for k, v in count.items():
    x.append(k)
    y.append(np.mean(v))

# %%
x = np.array(x)
y = np.array(y)
sort_index = np.argsort(x)
x = x[sort_index]
y = y[sort_index]

# %%
plt.plot(x[::30], y[::30])
plt.show()

# %%
plt.plot(x[::10], y[::10])
plt.show()
