# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#results = pd.read_csv("ppo-record-Amidar-v0.csv", index_col=0)
results = pd.read_csv("ppo-record-Centipede-v0.csv", index_col=0)

# %%
count = {
    
}

gamelength = {}

# %%
for i in range(results.shape[0]):
    episode = results.iloc[i, 0]
    reward = results.iloc[i, 2]
    if episode not in count.keys() and episode != 0:
        count[episode] = [reward]
    elif episode in count.keys():
        count[episode].append(reward)

# %%
x = []
y = []
for k, v in count.items():
    x.append(k)
    y.append(np.mean(v))

# %%
x = np.array(x)
y = np.array(y)
sort_index = np.argsort(x)
x = x[sort_index]
y = y[sort_index]

# %%
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# plt.rcParams['figure.figsize'] = (4.0, 2.0) # 设置figure_size尺寸

# %%
plt.plot(x[::30], y[::30],linewidth=0.8)
plt.xlabel("episode")
plt.ylabel("performance")
# plt.show()

plt.savefig('centipede.png', dpi=300)

# %%
# plt.plot(x[::10], y[::10])
# plt.show()

# %%
a = [1, 2, 3]

# %%
a = a[::-1]

# %%
a
# Out:
# [3, 2, 1]

# %%
a.extend([33, 4])

# %%
a
# Out:
# [3, 2, 1, 33, 4]
