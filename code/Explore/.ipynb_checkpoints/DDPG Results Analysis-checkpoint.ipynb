# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
#results = pd.read_csv("ppo-record-Amidar-v0.csv", index_col=0)
# results = pd.read_csv("ddpg-Ant-v2-2019-8-10-reward.csv", index_col=0)
# results = pd.read_csv("ddpg-HalfCheetah-v2-2019-8-10-reward.csv", index_col=0)
# results = pd.read_csv("ddpg-Humanoid-v2-2019-8-11-reward.csv", index_col=0)

# results = pd.read_csv("td3-Ant-v2-2019-8-10-reward.csv", index_col=0)
results = pd.read_csv("td3-Hopper-v2-2019-8-10-reward.csv", index_col=0)

# %%
y = results['0']
x = np.arange(1, len(y)+1)

# %%
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# plt.rcParams['figure.figsize'] = (4.0, 2.0) # 设置figure_size尺寸

# %%
plt.plot(x[::30], y[::30],linewidth=0.8)
plt.xlabel("episode")
plt.ylabel("performance")
# Out:
# Text(0, 0.5, 'performance')
